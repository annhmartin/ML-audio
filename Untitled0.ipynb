# %%
from google.colab import drive
drive.mount('/content/drive')

import os
DRIVE_DIR = '/content/drive/MyDrive/ML-Final Project-Audio/clotho'
assert os.path.isdir(DRIVE_DIR), f'Folder not found: {DRIVE_DIR}'
print('Files in your clotho folder:')
for f in sorted(os.listdir(DRIVE_DIR)):
    print('  ', f)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Files in your clotho folder:
#    cache
#    clotho_audio_development.7z
#    clotho_captions_development.csv
#    clotho_metadata_development.csv

# %%
import os, glob, subprocess

AUDIO_DIR = '/content/clotho_audio'
os.makedirs(AUDIO_DIR, exist_ok=True)

wavs = glob.glob(os.path.join(AUDIO_DIR, '**', '*.wav'), recursive=True)
if len(wavs) < 100:
    print('Installing 7z and extracting (a few minutes)...')
    subprocess.run(['apt-get', '-qq', 'install', '-y', 'p7zip-full'], check=True)
    archive = os.path.join(DRIVE_DIR, 'clotho_audio_development.7z')
    subprocess.run(['7z', 'x', archive, f'-o{AUDIO_DIR}', '-y'], check=True)
    wavs = glob.glob(os.path.join(AUDIO_DIR, '**', '*.wav'), recursive=True)

print(f'Found {len(wavs)} wav files')
print('Example:', wavs[0] if wavs else 'NONE — extraction failed')
assert len(wavs) > 100, 'Extraction did not produce the expected wav files'
# Out:
# Found 3839 wav files
# Example: /content/clotho_audio/development/TRAM1.wav

# %%
# !pip -q install laion-clap faiss-cpu librosa pandas 'numpy==1.26.4'
print('Installed. Now RESTART the runtime before continuing.')
# Out:
# Installed. Now RESTART the runtime before continuing.

# %%
import laion_clap

model = laion_clap.CLAP_Module(enable_fusion=False)
model.load_ckpt()   # downloads the pretrained checkpoint (~2 GB, one time)
print('CLAP loaded.')
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# ...

# %%
one = wavs[0]
emb = model.get_audio_embedding_from_filelist(x=[one], use_tensor=False)
print('Clip:', os.path.basename(one))
print('Embedding shape:', emb.shape)   # expect (1, 512)
print('First 5 values:', emb[0][:5])
assert emb.shape == (1, 512), 'Unexpected embedding shape'
print('\n✅ Backbone works.')
# Out:
# Clip: TRAM1.wav
# Embedding shape: (1, 512)
# First 5 values: [-0.02856455 -0.06707662 -0.02661136 -0.03990832 -0.01920557]
#
# ✅ Backbone works.

# %%
import pandas as pd, numpy as np, faiss

cap = pd.read_csv(os.path.join(DRIVE_DIR, 'clotho_captions_development.csv'), dtype=str)
cap = cap.set_index('file_name')
cap_cols = [c for c in cap.columns if c.lower().startswith('caption')]

name_to_path = {os.path.basename(p): p for p in wavs}
subset = [n for n in cap.index if n in name_to_path][:30]
paths = [name_to_path[n] for n in subset]
print(f'Embedding {len(paths)} clips...')

X = model.get_audio_embedding_from_filelist(x=paths, use_tensor=False).astype('float32')
faiss.normalize_L2(X)
index = faiss.IndexFlatIP(X.shape[1])
index.add(X)

D, I = index.search(X[0:1], 3)
q = subset[0]; nn = subset[I[0][1]]
print('\nQUERY  :', q)
print('  caption:', cap.loc[q, cap_cols[0]])
print('\nNEAREST:', nn, f'(similarity {D[0][1]:.3f})')
print('  caption:', cap.loc[nn, cap_cols[0]])
print('\nDo the two captions describe sounds? If yes, retrieval is sane. But might not be accurate yet.')
# Out:
# Embedding 30 clips...
#
# QUERY  : Distorted AM Radio noise.wav
#   caption: A muddled noise of broken channel of the TV
#
# NEAREST: broken comms2.wav (similarity 0.445)
#   caption: A radio cycling through stations as it is being repaired.
#
# Do the two captions describe sounds? If yes, retrieval is sane. But might not be accurate yet.

# %%
'''import numpy as np, json, time, gc, os, torch

CACHE_DIR  = os.path.join(DRIVE_DIR, 'cache'); os.makedirs(CACHE_DIR, exist_ok=True)
emb_path   = os.path.join(CACHE_DIR, 'dev_embeddings.npy')
names_path = os.path.join(CACHE_DIR, 'dev_filenames.json')
prog_emb   = os.path.join(CACHE_DIR, 'dev_emb_partial.npy')
prog_names = os.path.join(CACHE_DIR, 'dev_names_partial.json')

all_names = [n for n in cap.index if n in name_to_path]
all_paths = [name_to_path[n] for n in all_names]
N = len(all_paths)
print(f'{N} clips to embed')

if os.path.exists(prog_emb):                      # resume after a crash
    chunks = [np.load(prog_emb)]
    done_names = json.load(open(prog_names))
    start = len(done_names)
    print(f'Resuming from clip {start}')
else:
    chunks, done_names, start = [], [], 0

batch, t0 = 16, time.time()
for i in range(start, N, batch):
    e = model.get_audio_embedding_from_filelist(
            x=all_paths[i:i+batch], use_tensor=False).astype('float32')
    chunks.append(e)
    done_names += all_names[i:i+batch]
    if (i // batch) % 25 == 0:                     # checkpoint to Drive
        np.save(prog_emb, np.vstack(chunks))
        json.dump(done_names, open(prog_names, 'w'))
    print(f'  {min(i+batch, N)}/{N}  ({time.time()-t0:.0f}s)')
    gc.collect(); torch.cuda.empty_cache()

X_all = np.vstack(chunks)
np.save(emb_path, X_all)
json.dump(done_names, open(names_path, 'w'))
print('Saved embeddings:', X_all.shape)

# %%
import numpy as np, json, os
CACHE_DIR  = os.path.join(DRIVE_DIR, 'cache')
emb_path   = os.path.join(CACHE_DIR, 'dev_embeddings.npy')
names_path = os.path.join(CACHE_DIR, 'dev_filenames.json')

if os.path.exists(emb_path):
    X_all = np.load(emb_path)
    X_all = X_all / np.linalg.norm(X_all, axis=1, keepdims=True)
    all_names = json.load(open(names_path))
    print('Loaded cached embeddings instantly:', X_all.shape)
else:
    print('No cache yet — run the full embedding cell once.')
# Out:
# Loaded cached embeddings instantly: (3839, 512)

# %%
import faiss
Xn = X_all.copy()
faiss.normalize_L2(Xn)
full_index = faiss.IndexFlatIP(Xn.shape[1])
full_index.add(Xn)
faiss.write_index(full_index, os.path.join(CACHE_DIR, 'dev.index'))
print('Index built and saved:', full_index.ntotal, 'vectors')
# Out:
# Index built and saved: 3839 vectors

# %%
import numpy as np, random
Xn = X_all.astype('float32').copy()
faiss.normalize_L2(Xn)

random.seed(0)
for qi in random.sample(range(len(all_names)), 5):
    D, I = full_index.search(Xn[qi:qi+1], 3)
    q = all_names[qi]
    print('='*70)
    print('QUERY :', q)
    print('   ->', cap.loc[q, cap_cols[0]])
    for rank in [1, 2]:                 # rank 0 is the clip itself, skip it
        nn = all_names[I[0][rank]]
        print(f'NN{rank} (sim {D[0][rank]:.3f}):', nn)
        print('   ->', cap.loc[nn, cap_cols[0]])
# Out:
# ...
# QUERY : 140211-001 puka water.wav
#    -> Water burbles in a brook along a small stream.
# NN1 (sim 0.905): Small Creek.wav
#    -> A mass of water is draining down a pipe.
# NN2 (sim 0.902): 131227_strumyk_1.wav
#    -> A constant flow of water falling into a drain.
# ...
# QUERY : Swan_Signet_Honk and Rustle.wav
#    -> A person walks by as a goat bleats and birds chirp.
# NN1 (sim 0.619): chicken_freesound.wav
#    -> A chicken is clucking and flapping its wings
# NN2 (sim 0.606): Walking_on_tarmac.wav
#    -> A person is walking on rocks and gravel.
# ...
# QUERY : gardensoundscape.wav
#    -> Cars are racing down the track as birds are tweeting.
# NN1 (sim 0.840): Ambience - Merri path, birds, distant traffic, some cyclists.wav
#    -> A machine turns on over birds chirping while a car passes by.
# NN2 (sim 0.807): Atmos Residential Texas.wav
#    -> A sea animal dove and other birds are nearly drowned out by traffic in a nearby road.
# ...
# QUERY : BeesBuzzing2May2nd2015bitrate48.wav
# ...

# %%
import random
random.seed(1)
for qi in random.sample(range(len(all_names)), 5):
    D, I = full_index.search(Xn[qi:qi+1], 2)
    q  = all_names[qi]
    nn = all_names[I[0][1]]              # nearest *other* clip (skip itself)
    print('CLIP      :', q)
    print('  PREDICTED:', cap.loc[nn, cap_cols[0]])
    print('  TRUE     :', cap.loc[q,  cap_cols[0]], '\n')
# Out:
# CLIP      : pixies&amp;fairies.wav
#   PREDICTED: A keyboard synthesizer emits its slow electronic echoes
#   TRUE     : A sound synthesizer is creating different notes in a systematic way.
#
# CLIP      : marche1.wav
#   PREDICTED: A person is hiking through open land which is soft and damp so that the shoes make a sloshing sound.
#   TRUE     : A person walking along a dirt path outdoors while birds sing.
#
# CLIP      : Rain_Storm.wav
#   PREDICTED: It is raining and the rain is coming down on a sidewalk.
#   TRUE     : A downpour of rain lands on a window sill.
#
# CLIP      : final_version.wav
#   PREDICTED: A bell tolling in the foreground with some traffic noise.
#   TRUE     : Waves lap before a boat horn honks then the footsteps of a person crunch prior to a church bell dinging.
#
# CLIP      : Cola Into Glass.wav
#   PREDICTED: Someone is flipping over food on a hot grill.
#   TRUE     : A beverage with bubbles is poured from a container to glass.

# %%
import torch
import pandas as pd
from torch.utils.data import Dataset, DataLoader
from transformers import GPT2Tokenizer

# --- build readable (filename, caption) pairs, with a NaN/empty guard ---
training_pairs = []
for audio_name in all_names:
    if audio_name in cap.index:
        for col in cap_cols:
            caption_text = cap.loc[audio_name, col]
            if isinstance(caption_text, str) and caption_text.strip():
                training_pairs.append({'audio_filename': audio_name,
                                       'caption': caption_text.strip()})
training_df = pd.DataFrame(training_pairs)
print(f'Generated {len(training_df)} training pairs.')
display(training_df.head())

# --- tokenizer + map each row to its (normalized) embedding ---
tok = GPT2Tokenizer.from_pretrained('gpt2')
tok.pad_token = tok.eos_token
name_to_row = {n: i for i, n in enumerate(all_names)}   # filename -> row in X_all
MAX_LEN = 30

class CapDataset(Dataset):
    def __init__(self, df):
        self.df = df.reset_index(drop=True)
    def __len__(self):
        return len(self.df)
    def __getitem__(self, idx):
        r = self.df.iloc[idx]
        emb = torch.tensor(X_all[name_to_row[r['audio_filename']]], dtype=torch.float32)
        enc = tok(r['caption'] + tok.eos_token, truncation=True, max_length=MAX_LEN,
                  padding='max_length', return_tensors='pt')
        return emb, enc.input_ids[0], enc.attention_mask[0]

ds = CapDataset(training_df)
dl = DataLoader(ds, batch_size=64, shuffle=True)
emb, ids, m = next(iter(dl))
print('Batch -> embeddings:', emb.shape, '| tokens:', ids.shape)
# Out:
# Generated 19195 training pairs.
#                  audio_filename  \
# 0  Distorted AM Radio noise.wav
# 1  Distorted AM Radio noise.wav
# 2  Distorted AM Radio noise.wav
# 3  Distorted AM Radio noise.wav
# 4  Distorted AM Radio noise.wav
#
#                                              caption
# 0        A muddled noise of broken channel of the TV
# 1     A television blares the rhythm of a static TV.
# 2    Loud television static dips in and out of focus
# 3  The loud buzz of static constantly changes pit...
# 4  heavy static and the beginnings of a signal on...
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Batch -> embeddings: torch.Size([64, 512]) | tokens: torch.Size([64, 30])

# %%
# ===== STAGE 2: the model =====
import torch, torch.nn as nn
from transformers import GPT2LMHeadModel

PREFIX_LEN, GPT2_DIM = 10, 768

class MappingNetwork(nn.Module):
    def __init__(self, clap_dim=512, prefix_len=PREFIX_LEN, dim=GPT2_DIM):
        super().__init__()
        self.prefix_len, self.dim = prefix_len, dim
        self.net = nn.Sequential(
            nn.Linear(clap_dim, dim * prefix_len // 2),
            nn.Tanh(),
            nn.Linear(dim * prefix_len // 2, dim * prefix_len),
        )
    def forward(self, x):                          # x: (B, 512)
        return self.net(x).view(-1, self.prefix_len, self.dim)   # (B, P, 768)

class AudioCaptioner(nn.Module):
    def __init__(self):
        super().__init__()
        self.gpt = GPT2LMHeadModel.from_pretrained('gpt2')
        for p in self.gpt.parameters():            # freeze GPT-2
            p.requires_grad = False
        self.map = MappingNetwork()

    def forward(self, emb, input_ids, attn_mask):
        prefix    = self.map(emb)                              # (B, P, 768)
        tok_embed = self.gpt.transformer.wte(input_ids)        # (B, L, 768)
        inputs    = torch.cat([prefix, tok_embed], dim=1)      # (B, P+L, 768)

        B, P = prefix.shape[0], prefix.shape[1]
        prefix_mask = torch.ones(B, P, device=emb.device, dtype=attn_mask.dtype)
        mask = torch.cat([prefix_mask, attn_mask], dim=1)

        labels = input_ids.clone()
        labels[attn_mask == 0] = -100                          # ignore padding
        prefix_labels = torch.full((B, P), -100, device=emb.device, dtype=labels.dtype)
        labels = torch.cat([prefix_labels, labels], dim=1)     # ignore prefix too
        out = self.gpt(inputs_embeds=inputs, attention_mask=mask, labels=labels)
        return out.loss

device = 'cuda' if torch.cuda.is_available() else 'cpu'
captioner = AudioCaptioner().to(device)

emb, ids, m = next(iter(dl))
loss = captioner(emb.to(device), ids.to(device), m.to(device))
n_train = sum(p.numel() for p in captioner.parameters() if p.requires_grad)
print(f'Trainable params: {n_train:,}  (GPT-2 is frozen)')
print('Sanity loss on one batch:', loss.item())
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# [transformers] `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
# Trainable params: 31,468,800  (GPT-2 is frozen)
# Sanity loss on one batch: 9.100333213806152

# %%
# ===== STAGE 3: train the mapping network =====
import os
from torch.optim import AdamW
from tqdm import tqdm

opt = AdamW(captioner.map.parameters(), lr=2e-4)   # only the translator trains
EPOCHS = 10

captioner.train()
for ep in range(EPOCHS):
    tot = 0.0
    for emb, ids, m in tqdm(dl, desc=f'epoch {ep+1}/{EPOCHS}'):
        opt.zero_grad()
        loss = captioner(emb.to(device), ids.to(device), m.to(device))
        loss.backward()
        opt.step()
        tot += loss.item()
    print(f'  epoch {ep+1}: avg loss {tot/len(dl):.3f}')

ckpt = os.path.join(CACHE_DIR, 'mapping_net.pt')
torch.save(captioner.map.state_dict(), ckpt)        # save so you never retrain
print('Saved trained mapping network to', ckpt)
# Out:
# epoch 1/10: 100%|██████████| 300/300 [02:16<00:00,  2.19it/s]
#   epoch 1: avg loss 3.453
# epoch 2/10: 100%|██████████| 300/300 [02:33<00:00,  1.96it/s]
#   epoch 2: avg loss 3.175
# epoch 3/10: 100%|██████████| 300/300 [02:32<00:00,  1.96it/s]
#   epoch 3: avg loss 3.119
# epoch 4/10: 100%|██████████| 300/300 [02:32<00:00,  1.97it/s]
#   epoch 4: avg loss 3.089
# epoch 5/10: 100%|██████████| 300/300 [02:32<00:00,  1.97it/s]
#   epoch 5: avg loss 3.065
# epoch 6/10: 100%|██████████| 300/300 [02:32<00:00,  1.97it/s]
#   epoch 6: avg loss 3.043
# epoch 7/10: 100%|██████████| 300/300 [02:32<00:00,  1.97it/s]
#   epoch 7: avg loss 3.024
# epoch 8/10: 100%|██████████| 300/300 [02:32<00:00,  1.97it/s]
#   epoch 8: avg loss 3.010
# epoch 9/10: 100%|██████████| 300/300 [02:32<00:00,  1.97it/s]
#   epoch 9: avg loss 2.993
# epoch 10/10:  90%|█████████ | 270/300 [02:16<00:15,  1.98it/s]

# %%
# adding this cell when for skipping the cell above
captioner.map.load_state_dict(
    torch.load(os.path.join(CACHE_DIR, 'mapping_net.pt'), map_location=device))
captioner.eval()
print('Trained weights loaded.')
# Out:
# Trained weights loaded.

# %%
# ===== generate a caption from an audio embedding =====
import numpy as np, random

@torch.no_grad()
def caption_for(emb_vec, max_len=30):
    captioner.eval()
    v = np.asarray(emb_vec, dtype='float32')
    v = v / (np.linalg.norm(v) + 1e-9)              # same normalization as training
    emb = torch.tensor(v, device=device).unsqueeze(0)
    inputs, past, out_ids = captioner.map(emb), None, []
    for _ in range(max_len):
        o = captioner.gpt(inputs_embeds=inputs, past_key_values=past, use_cache=True)
        past = o.past_key_values
        nxt = o.logits[:, -1, :].argmax(-1)         # greedy: pick most likely word
        if nxt.item() == tok.eos_token_id:
            break
        out_ids.append(nxt.item())
        inputs = captioner.gpt.transformer.wte(nxt).unsqueeze(1)
    return tok.decode(out_ids).strip()

for n in random.sample(all_names, 5):
    print('CLIP   :', n)
    print('  MODEL:', caption_for(X_all[name_to_row[n]]))
    print('  TRUE :', cap.loc[n, cap_cols[0]], '\n')
# Out:
# CLIP   : stepshh.wav
#   MODEL: A person is hitting a ball with a stick.
#   TRUE : A ball is hit, then a man grunts while the ball continues on.
#
# CLIP   : FIELD_EVENINIG_02.wav
#   MODEL: A crickets are chirping in the background.
#   TRUE : Bugs are making noise outdoors as it is night time and a car drives by.
#
# CLIP   : Whistling antarctic blizzard.wav
#   MODEL: A wind blows on a windmill.
#   TRUE : A windy day finds someone cleaning stuff outside.
#
# CLIP   : slowwiper.wav
#   MODEL: A hammer is being struck repeatedly on a surface.
#   TRUE : A large number of banging sounds are being created in the distance
#
# CLIP   : creek.wav
#   MODEL: Water is flowing in a stream and birds are chirping.
#   TRUE : The water is flowing in a stream as several birds are singing farther away.

# %%
K = 3
hint_for = {}
Xn_all = X_all.astype('float32').copy(); faiss.normalize_L2(Xn_all)
Dn, In = full_index.search(Xn_all, K + 1)          # retrieve neighbors for all clips at once
for i, name in enumerate(all_names):
    neigh = [all_names[j] for j in In[i] if all_names[j] != name][:K]
    hint_for[name] = 'Similar sounds: ' + ' '.join(cap.loc[nm, cap_cols[0]] for nm in neigh) + ' Caption:'
print('Example hint:\n', hint_for[all_names[0]])
# Out:
# Example hint:
#  Similar sounds: Going through the dial on a radio, searching through the static for a station. A radio is being changed between multiple stations without settling on one. A pitch radio single goes up and down in tone in a random manner. Caption:

# %%
HINT_LEN, CAP_LEN = 64, 30
class RagDataset(Dataset):
    def __init__(self, df): self.df = df.reset_index(drop=True)
    def __len__(self): return len(self.df)
    def __getitem__(self, idx):
        r = self.df.iloc[idx]
        emb = torch.tensor(X_all[name_to_row[r['audio_filename']]], dtype=torch.float32)
        h = tok(hint_for[r['audio_filename']], truncation=True, max_length=HINT_LEN,
                padding='max_length', return_tensors='pt')
        c = tok(r['caption'] + tok.eos_token, truncation=True, max_length=CAP_LEN,
                padding='max_length', return_tensors='pt')
        return emb, h.input_ids[0], h.attention_mask[0], c.input_ids[0], c.attention_mask[0]
rag_dl = DataLoader(RagDataset(training_df), batch_size=64, shuffle=True)

# %%
from torch.optim import AdamW
from tqdm import tqdm  # adding these imports here so that we can skip the cell above that we don't need to keep rerunning

class RagCaptioner(nn.Module):
    def __init__(self):
        super().__init__()
        self.gpt = captioner.gpt           # same frozen GPT-2 as System A
        self.map = MappingNetwork()        # a NEW translator, trained WITH hints
    def forward(self, emb, hids, hmask, cids, cmask):
        prefix = self.map(emb)
        he = self.gpt.transformer.wte(hids); ce = self.gpt.transformer.wte(cids)
        inp = torch.cat([prefix, he, ce], dim=1)
        B, P = prefix.shape[0], prefix.shape[1]
        pmask = torch.ones(B, P, device=emb.device, dtype=hmask.dtype)
        mask = torch.cat([pmask, hmask, cmask], dim=1)
        labels = cids.clone(); labels[cmask == 0] = -100
        ignore = torch.full((B, P + hids.shape[1]), -100, device=emb.device, dtype=labels.dtype)
        labels = torch.cat([ignore, labels], dim=1)            # score ONLY the caption
        return self.gpt(inputs_embeds=inp, attention_mask=mask, labels=labels).loss

rag_model = RagCaptioner().to(device)
opt = AdamW(rag_model.map.parameters(), lr=2e-4)
scaler = torch.cuda.amp.GradScaler()
for ep in range(5):
    tot = 0.0
    for emb, hids, hmask, cids, cmask in tqdm(rag_dl, desc=f'RAG epoch {ep+1}/5'):
        opt.zero_grad()
        with torch.cuda.amp.autocast():
            loss = rag_model(emb.to(device), hids.to(device), hmask.to(device),
                             cids.to(device), cmask.to(device))
        scaler.scale(loss).backward(); scaler.step(opt); scaler.update()
        tot += loss.item()
    print(f'  RAG epoch {ep+1}: avg loss {tot/len(rag_dl):.3f}')
torch.save(rag_model.map.state_dict(), os.path.join(CACHE_DIR, 'rag_mapping_net.pt'))
# Out:
# /tmp/ipykernel_9699/2459358405.py:23: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# RAG epoch 1/5:   0%|          | 0/300 [00:00<?, ?it/s]/tmp/ipykernel_9699/2459358405.py:28: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# RAG epoch 1/5: 100%|██████████| 300/300 [02:41<00:00,  1.86it/s]
#   RAG epoch 1: avg loss 3.201
# RAG epoch 2/5: 100%|██████████| 300/300 [02:46<00:00,  1.81it/s]
#   RAG epoch 2: avg loss 2.944
# RAG epoch 3/5: 100%|██████████| 300/300 [02:48<00:00,  1.78it/s]
#   RAG epoch 3: avg loss 2.863
# RAG epoch 4/5: 100%|██████████| 300/300 [02:49<00:00,  1.77it/s]
#   RAG epoch 4: avg loss 2.797
# RAG epoch 5/5: 100%|██████████| 300/300 [02:49<00:00,  1.77it/s]
#   RAG epoch 5: avg loss 2.771

# %%
@torch.no_grad()
def rag_caption(name, max_len=30):
    rag_model.eval()
    v = X_all[name_to_row[name]].astype('float32'); v = v / (np.linalg.norm(v) + 1e-9)
    emb = torch.tensor(v, device=device).unsqueeze(0)
    hids = tok(hint_for[name], truncation=True, max_length=HINT_LEN, return_tensors='pt').input_ids.to(device)
    cur = torch.cat([rag_model.map(emb), rag_model.gpt.transformer.wte(hids)], dim=1)
    past, out = None, []
    for _ in range(max_len):
        o = rag_model.gpt(inputs_embeds=cur, past_key_values=past, use_cache=True)
        past = o.past_key_values
        nxt = o.logits[:, -1, :].argmax(-1)
        if nxt.item() == tok.eos_token_id: break
        out.append(nxt.item())
        cur = rag_model.gpt.transformer.wte(nxt).unsqueeze(1)
    return tok.decode(out).strip()

for n in random.sample(all_names, 5):
    print('CLIP :', n)
    print('  A   :', caption_for(X_all[name_to_row[n]]))
    print('  B   :', rag_caption(n))
    print('  TRUE:', cap.loc[n, cap_cols[0]], '\n')
# Out:
# CLIP : Nord_Odal_Nyhus_04_juni_2011_quiet_forest_birds_insects_distant_chainsaw_01.wav
#   A   : Birds are chirping and the wind is blowing.
#   B   : Birds chirp in the background while a car drives by.
#   TRUE: A driver revs their engine aggressively drowning out nearby bird chirps.
#
# CLIP : Dentist Chair Hydraulics.wav
#   A   : A machine is running and a person is being fed.
#   B   : A machine is running and then a buzz sees a buzz.
#   TRUE: A machine is running until it turns off and then turns back on.
#
# CLIP : Walking on Snow 001.wav
#   A   : Someone is walking on gravel and then they are walking on snow.
#   B   : A person is walking on a gravel surface.
#   TRUE: Rhythmic, continuous stepping with crunching along the way until the stepping slows down.
#
# CLIP : Leaves rustling.wav
#   A   : A person is walking on a grassy area.
#   B   : A person walks on a snow-covered surface and is walking on a snow-covered surface.
# ...

# %%
# ===== STAGE 4: automatic metrics =====
# !pip -q install pycocoevalcap pycocotools

import json, random
from pycocoevalcap.bleu.bleu import Bleu
from pycocoevalcap.meteor.meteor import Meteor
from pycocoevalcap.cider.cider import Cider

def evaluate_system(name, caption_fn, sample_names, cap, cap_cols):
    """Score a captioning system against all 5 ground truth captions."""
    refs, hyps = {}, {}
    print(f'Generating captions for {name}...')
    for i, n in enumerate(sample_names):
        hyps[i] = [caption_fn(n)]
        refs[i]  = [cap.loc[n, col] for col in cap_cols
                    if isinstance(cap.loc[n, col], str) and cap.loc[n, col].strip()]
    scorers = [
        (Bleu(4),   ['BLEU-1','BLEU-2','BLEU-3','BLEU-4']),
        (Meteor(),  ['METEOR']),
        (Cider(),   ['CIDEr']),
    ]
    scores = {}
    for scorer, names in scorers:
        score, _ = scorer.compute_score(refs, hyps)
        if isinstance(score, list):
            for n2, s in zip(names, score):
                scores[n2] = round(s, 4)
        else:
            scores[names[0]] = round(score, 4)
    return scores

# Use a fixed sample of 200 clips for eval
random.seed(42)
eval_names = random.sample(all_names, 200)

# Retrieval baseline: nearest neighbor caption (System 0)
def retrieval_caption(name):
    v = X_all[name_to_row[name]].astype('float32').copy()
    v = v / (np.linalg.norm(v) + 1e-9)
    D, I = full_index.search(v.reshape(1,-1), 2)
    nn = all_names[I[0][1]]
    return cap.loc[nn, cap_cols[0]]

# System A: direct captioning
def system_a_caption(name):
    return caption_for(X_all[name_to_row[name]])

# System B: retrieval-assisted
def system_b_caption(name):
    return rag_caption(name)

results = {}
results['Retrieval baseline'] = evaluate_system('Retrieval baseline', retrieval_caption, eval_names, cap, cap_cols)
results['System A (direct)']  = evaluate_system('System A (direct)',  system_a_caption,  eval_names, cap, cap_cols)
results['System B (RAG)']     = evaluate_system('System B (RAG)',     system_b_caption,  eval_names, cap, cap_cols)

print('\n=== Results ===')
metrics = ['BLEU-1','BLEU-2','BLEU-3','BLEU-4','METEOR','CIDEr']
header = f"{'System':<25}" + ''.join(f'{m:>10}' for m in metrics)
print(header)
print('-' * len(header))
for sys_name, scores in results.items():
    row = f"{sys_name:<25}" + ''.join(f"{scores.get(m, 0):>10.4f}" for m in metrics)
    print(row)

json.dump(results, open(os.path.join(CACHE_DIR, 'eval_results.json'), 'w'), indent=2)
print('\nSaved to cache.')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 8.9 MB/s eta 0:00:00
# Generating captions for Retrieval baseline...
# {'testlen': 2285, 'reflen': 2218, 'guess': [2285, 2085, 1885, 1685], 'correct': [861, 187, 47, 9]}
# ratio: 1.0302073940482281
# Generating captions for System A (direct)...
# {'testlen': 1943, 'reflen': 2042, 'guess': [1943, 1743, 1543, 1343], 'correct': [1091, 359, 118, 37]}
# ratio: 0.9515181194902295
# Generating captions for System B (RAG)...
# {'testlen': 2092, 'reflen': 2115, 'guess': [2092, 1892, 1692, 1492], 'correct': [1090, 356, 109, 25]}
# ratio: 0.9891252955078066
#
# === Results ===
# System                       BLEU-1    BLEU-2    BLEU-3    BLEU-4    METEOR     CIDEr
# -------------------------------------------------------------------------------------
# Retrieval baseline           0.3768    0.1838    0.0945    0.0461    0.1400    0.1695
# System A (direct)            0.5336    0.3232    0.1965    0.1187    0.1776    0.3095
# ...

# %%
# ===== STAGE 5: error analysis =====
import pandas as pd

random.seed(7)
analysis_names = random.sample(all_names, 50)

rows = []
for n in analysis_names:
    true_cap   = cap.loc[n, cap_cols[0]]
    pred_a     = system_a_caption(n)
    pred_b     = system_b_caption(n)
    pred_ret   = retrieval_caption(n)

    # simple word overlap as a proxy for per-clip quality
    def overlap(pred, ref):
        p, r = set(pred.lower().split()), set(ref.lower().split())
        return len(p & r) / max(len(r), 1)

    rows.append({
        'filename'   : n,
        'true'       : true_cap,
        'retrieval'  : pred_ret,
        'system_a'   : pred_a,
        'system_b'   : pred_b,
        'overlap_ret': round(overlap(pred_ret, true_cap), 3),
        'overlap_a'  : round(overlap(pred_a,   true_cap), 3),
        'overlap_b'  : round(overlap(pred_b,   true_cap), 3),
    })

df_err = pd.DataFrame(rows)

# Worst cases for System A — clips where it struggled most
print('=== 5 worst clips for System A ===')
worst_a = df_err.nsmallest(5, 'overlap_a')[['filename','true','system_a','overlap_a']]
for _, r in worst_a.iterrows():
    print(f'\nFILE  : {r.filename}')
    print(f'TRUE  : {r.true}')
    print(f'PRED  : {r.system_a}')
    print(f'SCORE : {r.overlap_a}')

# Where System B beats System A most
df_err['b_gain'] = df_err['overlap_b'] - df_err['overlap_a']
print('\n=== 5 clips where RAG helped most ===')
best_rag = df_err.nlargest(5, 'b_gain')[['filename','true','system_a','system_b','b_gain']]
for _, r in best_rag.iterrows():
    print(f'\nFILE  : {r.filename}')
    print(f'TRUE  : {r.true}')
    print(f'A     : {r.system_a}')
    print(f'B     : {r.system_b}')
    print(f'GAIN  : {r.b_gain:+.3f}')

# Where retrieval beats both models
df_err['ret_best'] = (df_err['overlap_ret'] > df_err['overlap_a']) & \
                     (df_err['overlap_ret'] > df_err['overlap_b'])
print(f'\nClips where retrieval baseline beats both models: {df_err.ret_best.sum()}/50')

df_err.to_csv(os.path.join(CACHE_DIR, 'error_analysis.csv'), index=False)
print('Saved error_analysis.csv')
# Out:
# === 5 worst clips for System A ===
#
# FILE  : Tokyo - Hiroo street.wav
# TRUE  : Individuals talk out of sight while various autos drive by.
# PRED  : A car is driving by and a person is talking.
# SCORE : 0.0
#
# FILE  : Water2.wav
# TRUE  : A mechanical hissing noise dissipates and then comes a muffled, ambient melody that gets louder as time progresses.
# PRED  : A wave is being played in the background.
# SCORE : 0.059
#
# FILE  : Printer Setting Up.wav
# TRUE  : A car door opens while the engine hums at a low level.
# PRED  : A printer is being printed on a paper.
# SCORE : 0.091
#
# FILE  : deadbolt lock.wav
# TRUE  : A stapler was punching against some paper for every few seconds.
# PRED  : A door is being opened and closed repeatedly.
# SCORE : 0.091
#
# FILE  : Crane ship unloading sand 1.wav
# TRUE  : Bangs and buzzes proceed from working machinery in the background.
# PRED  : A truck is moving and a truck is moving.
# SCORE : 0.1
#
# === 5 clips where RAG helped most ===
# ...

# %%
# ===== STAGE 6: comparison table =====
import pandas as pd

df_results = pd.DataFrame(results).T
df_results.index.name = 'System'
df_results = df_results[['BLEU-1','BLEU-2','BLEU-3','BLEU-4','METEOR','CIDEr']]

# Highlight the best score in each column
def highlight_best(col):
    is_best = col == col.max()
    return ['font-weight: bold' if v else '' for v in is_best]

display(df_results.style
    .apply(highlight_best)
    .format('{:.4f}')
    .set_caption('Table 1: Automatic evaluation metrics across three systems (n=200 clips)'))

# Summary stats from error analysis
print('\n=== Error analysis summary ===')
print(f"Mean word overlap — Retrieval : {df_err['overlap_ret'].mean():.3f}")
print(f"Mean word overlap — System A  : {df_err['overlap_a'].mean():.3f}")
print(f"Mean word overlap — System B  : {df_err['overlap_b'].mean():.3f}")
print(f"\nSystem B beats System A on   : {(df_err['overlap_b'] > df_err['overlap_a']).sum()}/50 clips")
print(f"Retrieval beats both models  : {df_err['ret_best'].sum()}/50 clips")
print(f"\nLargest RAG gain clip        : {df_err.loc[df_err['b_gain'].idxmax(), 'filename']}")
print(f"Largest RAG gain value       : {df_err['b_gain'].max():+.3f}")
# Out:
# <style type="text/css">
# #T_5f880_row1_col0, #T_5f880_row1_col1, #T_5f880_row1_col2, #T_5f880_row1_col3, #T_5f880_row1_col4, #T_5f880_row1_col5 {
#   font-weight: bold;
# }
# </style>
# <table id="T_5f880" class="dataframe">
#   <caption>Table 1: Automatic evaluation metrics across three systems (n=200 clips)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f880_level0_col0" class="col_heading level0 col0" >BLEU-1</th>
#       <th id="T_5f880_level0_col1" class="col_heading level0 col1" >BLEU-2</th>
#       <th id="T_5f880_level0_col2" class="col_heading level0 col2" >BLEU-3</th>
#       <th id="T_5f880_level0_col3" class="col_heading level0 col3" >BLEU-4</th>
#       <th id="T_5f880_level0_col4" class="col_heading level0 col4" >METEOR</th>
#       <th id="T_5f880_level0_col5" class="col_heading level0 col5" >CIDEr</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >System</th>
# ...
